# %% [markdown]
# # Audio Signal Processing - Part1
#
# We will first learn simple audio processing tasks such as loading an audio file, displaying its characteristics (e.g. sampling rate and duration), and plotting the signal.

# %%
# import all necessary libraries 
import numpy as np
import librosa
import librosa.display
import IPython.display as ipd
import matplotlib.pyplot as plt

# %%
# set the path to the audio file
file_path = "C:/Users/Asus/Documents/COVID19/1599668564710.aac"

# %%
# play the audio file
ipd.Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/vnd.dlna.adts;base64,..." type="audio/vnd.dlna.adts" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# To play an audio in your local machine, you can use any other python library.
# For example, playsound, simpleaudio, pygame, vlc, and many others.

# %%
# display the information about the audio file
! ffprobe kazakh_utterance.mp3
# Out:
# "ffprobe" не является внутренней или внешней
# командой, исполняемой программой или пакетным файлом.

# %% [markdown]
# "ffprobe" is a simple multimedia stream analyzer. You can use it to output all kinds of information about an input audio file including duration, sampling rate, number of channels, etc. It is also useful for gathering specific information about an input to be used in a script. Note that there are many other tools that can extract audio information and you can use whichever you like.

# %% [markdown]
# ## Load the audio file
#
# We will use the [Librosa](https://librosa.org/) library to perform the signal processing operations.
#
# The first operation that we will perform is the file loading.
# The loaded audio will be represented as a time series data (one-dimensional numpy array of floating-point values). The *audio[t]* corresponds to amplitude of the waveform at sample *t*.
#
# The variable **sr** will store the sampling rate of the loaded audio, i.e. the number of samples per second of audio.
# By default, the audio is resampled to 22,050 Hz at load time. Note that the original audio's sampling rate is 48,000 Hz, thus, we downsampled the audio to 22,050 Hz.

# %%
audio, sr = librosa.load(file_path)
print("Type: ", type(audio))  # python data type
print("Size: ", len(audio))   # or print(audio.size), total number of samples
print("The first sample: ", audio[0]) # the value of the first sample
print("Sample type: ", type(audio[0]))  # python data type of a sample
print("Sampling rate: ", sr)   # sampling rate of the loaded audio
# Out:
# Type:  <class 'numpy.ndarray'>
# Size:  112014
# The first sample:  0.00089695887
# Sample type:  <class 'numpy.float32'>
# Sampling rate:  22050

# %% [markdown]
# ## Your turn - compute the sampling period

# %%
# write your code here.
# Sampling period, i.e. time duration between two samples
period = 1/sr

# %%
# check you code
print(f"Period: {period} sec")
# Out:
# Period: 4.5351473922902495e-05 sec

# %% [markdown]
# ## Your turn - compute the total audio duration

# %%
# write your code here
# Total duration of the audio signal
duration = period*audio.size

# %%
# check you code
print(f"Duration: {duration} sec")
# Out:
# Duration: 5.08 sec

# %% [markdown]
# ## Your turn - find the minimum and maximum signal values

# %%
# write your code here (hint: use numpy functions)
max_value = audio.max()     # the maximum amplitude value in audio signal
min_value =  audio.min()     # the minimum amplitude value in audio signal

# %%
# check you code
print("Max:", max_value)
print("Min:", min_value)
# Out:
# Max: 0.7558891
# Min: -0.72660184

# %% [markdown]
# ## Plot the time-domain signal

# %%
# Plot the time-domain signal using librosa
librosa.display.waveplot(audio)

# %%
# Plot the time-domain signal using matplotlib
time  = [period*i for i in range(audio.size)]
#time = librosa.frames_to_time(range(audio.size), sr=sr, hop_length=1)  # try librosa library to compute time steps
plt.figure(figsize=(25, 5))  # set the figure size
plt.plot(time, audio)
#plt.plot(time[:100], audio[:100],"bo")   # print the first 100 samples
plt.xlabel("Time")
plt.show()

# %%
#plt.plot(time[:100], audio[:100],"b")   # print the first 100 samples

# %%
# let's compare time steps computed using our python implementation and librosa
time  = [period*i for i in range(audio.size)]
time_librosa = librosa.frames_to_time(range(audio.size), sr=sr, hop_length=1)

for i in range(20):
  print(f"{i}: {time[i]} \t {time_librosa[i]}")

# Notice that the librosa's implementation is almost similar to ours (check the samples at position 15 which has slight difference).
# Out:
# 0: 0.0 	 0.0
# 1: 4.5351473922902495e-05 	 4.5351473922902495e-05
# 2: 9.070294784580499e-05 	 9.070294784580499e-05
# 3: 0.00013605442176870748 	 0.00013605442176870748
# 4: 0.00018140589569160998 	 0.00018140589569160998
# 5: 0.00022675736961451248 	 0.00022675736961451248
# 6: 0.00027210884353741496 	 0.00027210884353741496
# 7: 0.00031746031746031746 	 0.00031746031746031746
# 8: 0.00036281179138321996 	 0.00036281179138321996
# 9: 0.00040816326530612246 	 0.00040816326530612246
# 10: 0.00045351473922902497 	 0.00045351473922902497
# 11: 0.0004988662131519275 	 0.0004988662131519275
# 12: 0.0005442176870748299 	 0.0005442176870748299
# 13: 0.0005895691609977325 	 0.0005895691609977325
# 14: 0.0006349206349206349 	 0.0006349206349206349
# 15: 0.0006802721088435375 	 0.0006802721088435374
# 16: 0.0007256235827664399 	 0.0007256235827664399
# 17: 0.0007709750566893424 	 0.0007709750566893424
# 18: 0.0008163265306122449 	 0.0008163265306122449
# 19: 0.0008616780045351474 	 0.0008616780045351474

# %% [markdown]
# ## Extracting time-domain features
#
# We will learn to extract two time-domain feature types: amplitude envelope (AE) and root mean square (RMS) energy. We will try both librosa and our own implementations.
#
# The first step is to split the input audio signal into the frames, i.e. framing. A frame is a short signal segment (e.g. 25 ms).
#
# Next, from each frame we will extract a single feature value / vector / matrix / tensor.

# %% [markdown]
# ![framing.png](data:image/png;base64,...)

# %% [markdown]
# ### Amplitude envelope feature
#
# Maximum amplitude value of all samples in a frame.
#
# ![AmplitudeEnvelopeFormula.PNG](data:image/png;base64,...)

# %% [markdown]
# $AE_t$ - amplitude envelope at frame $t$
#
# $s(k)$ - amplitude of $k$-th sample
#
# $K$ - frame size (number of samples in a single frame)
#
# $k=t\cdot K$ - first sample of frame $t$
#
# $(t+1)\cdot K-1$ - last sample of frame $t$
#
#
# In amplitude envelope, each frame is represented by its largest sample value, i.e. from each frame we will extract a single value.

# %%
# calculate the amplitude envelope from the non-overlapping frames

def amplitude_envelope(signal, frame_length):
  amplitude_envelope = []
  # calculate AE for each frame
  for i in range(0, len(signal), frame_length):
    current_frame_AE = max(signal[i:i+frame_length])
    amplitude_envelope.append(current_frame_AE)
  return np.array(amplitude_envelope)

# %%
FRAME_LENGTH = 1024

AE_audio = amplitude_envelope(audio, FRAME_LENGTH)
print("Size: ", len(AE_audio))   # total number of AE features
# Out:
# Size:  110

# %%
amplitude_envelope(audio, FRAME_LENGTH)
# Out:
# array([0.01613976, 0.01457964, 0.01474268, 0.01846531, 0.01274171,
#        0.01403417, 0.0205093 , 0.03003109, 0.06127407, 0.07318645,
#        0.05986555, 0.07375468, 0.07463494, 0.06536613, 0.04720798,
#        0.03320033, 0.04296239, 0.02425047, 0.02316355, 0.02254506,
#        0.01974748, 0.11315267, 0.01289648, 0.05473778, 0.00562383,
#        0.00271019, 0.00307045, 0.00389766, 0.00294649, 0.00268304,
#        0.00336029, 0.06717625, 0.05876633, 0.04498403, 0.7558891 ,
#        0.7292424 , 0.70854694, 0.69180536, 0.7091491 , 0.63445663,
#        0.44415498, 0.6584223 , 0.6113814 , 0.69675887, 0.10204884,
#        0.03445094, 0.2873384 , 0.6856919 , 0.58515096, 0.5365163 ,
#        0.15977447, 0.284376  , 0.17682742, 0.02282749, 0.00754456,
#        0.00762761, 0.0142323 , 0.01543649, 0.0276985 , 0.02742741,
#        0.02407267, 0.02698257, 0.03370631, 0.02826444, 0.01939715,
#        0.05718344, 0.04674767, 0.05435815, 0.05299131, 0.06623851,
#        0.04101431, 0.01121361, 0.00830092, 0.00782839, 0.0074525 ,
#        0.00859294, 0.03720419, 0.04524221, 0.48355782, 0.7198169 ,
#        0.6102532 , 0.72342765, 0.7095236 , 0.7275586 , 0.52494735,
#        0.06462111, 0.04064579, 0.020422  , 0.27510494, 0.6352405 ,
#        0.31106383, 0.30137968, 0.34589928, 0.09607462, 0.03917225,
#        0.02905934, 0.01315711, 0.00851107, 0.00788626, 0.00743034,
#        0.00731302, 0.0075773 , 0.00925043, 0.33540365, 0.250899  ,
#        0.19836092, 0.11406588, 0.08824286, 0.02656123, 0.02656123],
#       dtype=float32)

# %% [markdown]
# #### AE features from the overlapping frames

# %%
# calculate the amplitude envelope from the overlapping 

def amplitude_envelope_ol(signal, frame_length, hop_length):
  amplitude_envelope = []
  # calculate AE for each frame
  for i in range(0, len(signal), hop_length):
    current_frame_AE = max(signal[i:i+frame_length])
    amplitude_envelope.append(current_frame_AE)
  return np.array(amplitude_envelope)

# %%
FRAME_LENGTH = 1024
HOP_LENGTH = 512

AE_OL_audio = amplitude_envelope_ol(audio, FRAME_LENGTH, HOP_LENGTH)
print("Size: ", len(AE_OL_audio))   # total number of AE features
# Out:
# Size:  219

# %% [markdown]
# ### Your turn - optimize the AE computation function
#
# Rewrite the "amplitude_envelope(signal, frame_size)" function using a single line.

# %%
# Write your code here

def amplitude_envelope_1line(signal, frame_length):
    current_AE= [max(signal[i:i+frame_length]) for i in range(0, len(signal), frame_length)]
    return  current_AE

# %%
AE=amplitude_envelope_1line(audio, 1024)
print(AE)
# Out:
# [0.01613976, 0.014579635, 0.01474268, 0.01846531, 0.012741707, 0.014034167, 0.020509303, 0.030031085, 0.061274067, 0.07318645, 0.05986555, 0.07375468, 0.07463494, 0.06536613, 0.04720798, 0.033200327, 0.042962395, 0.024250474, 0.023163548, 0.022545058, 0.019747479, 0.11315267, 0.012896476, 0.05473778, 0.00562383, 0.002710188, 0.0030704471, 0.0038976574, 0.0029464876, 0.0026830386, 0.003360295, 0.06717625, 0.058766328, 0.044984028, 0.7558891, 0.7292424, 0.70854694, 0.69180536, 0.7091491, 0.63445663, 0.44415498, 0.6584223, 0.6113814, 0.69675887, 0.10204884, 0.034450937, 0.2873384, 0.6856919, 0.58515096, 0.5365163, 0.15977447, 0.284376, 0.17682742, 0.022827491, 0.0075445618, 0.0076276083, 0.0142322965, 0.015436494, 0.027698496, 0.027427409, 0.024072668, 0.026982568, 0.03370631, 0.028264442, 0.01939715, 0.05718344, 0.046747666, 0.054358155, 0.052991312, 0.06623851, 0.041014314, 0.011213608, 0.008300923, 0.00782839, 0.0074525042, 0.008592938, 0.037204195, 0.04524221, 0.48355782, 0.7198169, 0.6102532, 0.72342765, 0.7095236, 0.7275586, 0.52494735, 0.064621106, 0.04064579, 0.020421999, 0.27510494, 0.6352405, 0.31106383, 0.30137968, 0.34589928, 0.09607462, 0.039172255, 0.029059343, 0.013157108, 0.008511068, 0.007886263, 0.007430337, 0.0073130205, 0.007577303, 0.009250429, 0.33540365, 0.250899, 0.19836092, 0.11406588, 0.08824286, 0.026561232, 0.026561232]

# %%
# Check your code
FRAME_LENGTH = 1024

AE_audio = amplitude_envelope(audio, FRAME_LENGTH)
AE_audio_1line = amplitude_envelope_1line(audio, FRAME_LENGTH)

print((AE_audio == AE_audio_1line).all())
# Out:
# True

# %% [markdown]
# **Expected output**
#
# True

# %% [markdown]
# ### Visualize AE

# %%
# Plot the time-domain signal using matplotlib
time  = [period*i for i in range(audio.size)]
time_AE = [period*i for i in range(0, audio.size, FRAME_LENGTH)]
#time = librosa.frames_to_time(range(audio.size), sr=sr, hop_length=1)  # try librosa library to compute time steps
plt.figure(figsize=(25, 5))  # set the figure size
plt.plot(time, audio)
plt.plot(time_AE, AE_audio, "r.")
plt.xlabel("Time")
plt.ylim(-1,1)
plt.show()

# %% [markdown]
# ### Extracting RMSE

# %% [markdown]
# ![RMSE_formula.PNG](data:image/png;base64,...)

# %% [markdown]
# #### Extract RMSE using librosa

# %%
FRAME_LENGTH = 1024
HOP_LENGTH = 512

RMSE_audio = librosa.feature.rms(audio, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH)[0]

# %%
print(RMSE_audio.shape)
# Out:
# (219,)

# %%
# Plot the time-domain signal using matplotlib
time  = [period*i for i in range(audio.size)]
time_RMSE = [period*i for i in range(0, audio.size, HOP_LENGTH)]
#time_RMSE = librosa.frames_to_time(range(RMSE_audio.size), sr=sr, hop_length=HOP_LENGTH)  # try librosa library to compute time steps
plt.figure(figsize=(25, 5))  # set the figure size
plt.plot(time, audio)
plt.plot(time_RMSE, RMSE_audio, "r.")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# ### Your turn - write the RMSE function

# %%
# your code
# The function should extract the RMSE features from the overlapping frames (hint: see the AE feature extraction code)

def rmse(signal, frame_length, hop_length):
    rmse = []
  # calculate AE for each frame
    for i in range(0, len(signal), hop_length):
        current_frame_rms = np.sqrt((signal[i:i+frame_length]**2).mean())
        rmse.append(current_frame_rms)
    return np.array(rmse)

# %%
# check you code
RMSE_audio2 = rmse(audio, FRAME_LENGTH, HOP_LENGTH)

# %%
# Plot the time-domain signal using matplotlib
time  = [period*i for i in range(audio.size)]
#time_RMSE = [period*i for i in range(0, audio.size, HOP_LENGTH)]
time_RMSE = librosa.frames_to_time(range(RMSE_audio.size), sr=sr, hop_length=HOP_LENGTH)  # try librosa library to compute time steps
#time_RMSE2 = time_RMSE
time_RMSE2 = time_RMSE + 512*period
plt.figure(figsize=(25, 5))  # set the figure size
plt.plot(time, audio)
plt.plot(time_RMSE, RMSE_audio, "ro")
plt.plot(time_RMSE2, RMSE_audio2, "y.")
plt.xlabel("Time")
plt.show()

# %%
##SALTANAT KHALYK

# %%
import matplotlib.pyplot as plt
y, sr = librosa.load(file_path)
S = np.abs(librosa.stft(y))
fig, ax = plt.subplots()
img = librosa.display.specshow(librosa.amplitude_to_db(S,
                                                       ref=np.max),
                               y_axis='log', x_axis='time', ax=ax)
ax.set_title('Power spectrogram')
fig.colorbar(img, ax=ax, format="%+2.0f dB")

# %%
X = librosa.stft(audio)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
cough_ft= np.fft.fft(y)

# %%
cough_ft.shape
# Out:
# (112014,)

# %%
cough_ft[0]
# Out:
# (-118.96268040812588+0j)

# %%
magnitude_spectrum_cough_ft =np.abs(cough_ft)

# %%
magnitude_spectrum_cough_ft[0]
# Out:
# 118.96268040812588

# %%
def plot_magnitude_spectrum(signal, title, sr):
    ft= np.fft.fft(signal)
    magnitude_spectrum=np.abs(ft)
    
    #plot magnitude spectrum
    
    frequency =np.linspace(0, sr, len(magnitude_spectrum))
    plt.plot(frequency, magnitude_spectrum)
    plt.xlabel('frequency (HZ)')
    plt.title(title)
    
    plt.show()

# %%
plot_magnitude_spectrum(y, 'cough', sr)

# %% [markdown]
# ## Zero crossing rate
#
# the rate at which the signal changes from positive to zero to negative or from negative to zero to positive. This feature has been used heavily in both speech recognition and music information retrieval, being a key feature to classify percussive sounds.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
FRAME_LENGTH = 1024
HOP_LENGTH = 512
zcr_sound = librosa.feature.zero_crossing_rate(audio, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH)[0]

# %%
period = 1/sr
time  = [period*i for i in range(audio.size)]
#time_RMSE = [period*i for i in range(0, audio.size, HOP_LENGTH)]
time_zcr = librosa.frames_to_time(range(zcr_sound.size), sr=sr, hop_length=HOP_LENGTH)  # try librosa library to compute time steps

plt.figure(figsize=(25, 5))  # set the figure size
plt.plot(time, audio)
plt.plot(time_zcr, zcr_sound, "ro")

plt.xlabel("Time")
plt.show()

# %%
frames = range(0, len(zcr_sound))
t = librosa.frames_to_time(frames, hop_length =HOP_LENGTH)

plt.figure(figsize =(15,17))

ax = plt.subplot(3,1,1)
librosa.display.waveplot(audio, alpha= 0.5)
plt.plot(t, zcr_sound, color='r')
plt.ylim((-1,1))
plt.title('Covid sound')
plt.show()

# %%
plt.figure(figsize =(15,5))
plt.plot(t, zcr_sound, color = 'y')
plt.ylim((0,1))
plt.show()

# %% [markdown]
# Band energy [proportion of high and low frequency]

# %%
FRAME_SIZE= 2048
HOP_SIZE = 512

cov_sound_spec = librosa.stft(audio, n_fft = FRAME_SIZE, hop_length =HOP_SIZE)

# %%
cov_sound_spec.shape
# Out:
# (1025, 219)

# %% [markdown]
# ## CALCULATE BAND ENERGY RATIO

# %%
def calculate_split_frequency_bin (spectrogram, split_frequency, sample_rate):
    frequency_range = sample_rate / 2
    frequency_delta_per_bin = frequency_range / spectrogram.shape[0]
    split_frequency_bin = np.floor(split_frequency / frequency_delta_per_bin)
    return int(split_frequency_bin)

# %%
split_frequency_bin = calculate_split_frequency_bin (cov_sound_spec, 2000, 22050)
split_frequency_bin
# Out:
# 185

# %%
def calculate_band_energy_ratio (spectrogram, split_frequency, sample_rate):
    split_frequency_bin = calculate_split_frequency_bin(spectrogram, split_frequency, sample_rate)
    
    power_spec = np.abs(spectrogram)**2
    power_spec = power_spec.T
    
    band_energy_ratio = []
    
    for frequencies_in_frame in power_spec:
        sum_power_low_frequencies = np.sum(frequencies_in_frame[:split_frequency_bin])
        sum_power_high_frequencies = np.sum(frequencies_in_frame[split_frequency_bin:])
        ber_current_frame = sum_power_low_frequencies/sum_power_high_frequencies
        band_energy_ratio.append(ber_current_frame)
        
    return np.array(band_energy_ratio)

# %%
ber_cov_sound = calculate_band_energy_ratio(cov_sound_spec, 2000, sr)

# %%
ber_cov_sound.shape
# Out:
# (219,)

# %% [markdown]
# VISUALIZE BAND ENERGY RATIO CURVES

# %%
frames = range(len(ber_cov_sound))
t= librosa.frames_to_time(frames, hop_length =HOP_SIZE)

# %%
len(t)
# Out:
# 219

# %%
plt.figure(figsize =(25,10))

plt.plot(t, ber_cov_sound, color = 'b')
plt.show()

# %% [markdown]
# ## SPECTRAL CENTROID WITH LIBROSA

# %%
FRAME_SIZE = 1024
HOP_LENGTH =512

sc_cov_sound= librosa.feature.spectral_centroid( y  = audio, sr  =sr, n_fft=FRAME_SIZE, hop_length= HOP_LENGTH)[0]

# %%
frames = range(len(sc_cov_sound))
t= librosa.frames_to_time(frames)

# %%
plt.figure(figsize= (25,10))
plt.plot(t, sc_cov_sound, color= 'g')

plt.show()

# %% [markdown]
# ## CALCULATE BANDWIDTH

# %%
 sb_cov_sound= librosa.feature.spectral_bandwidth( y  = audio, sr  =sr, n_fft=FRAME_SIZE, hop_length= HOP_LENGTH)[0]

# %%
plt.figure(figsize= (25,10))
plt.plot(t, sb_cov_sound, color= 'g')

plt.show()

# %% [markdown]
#  ## Feature extraction:
#     # amplitude envelope
#     # root mean square
#     # zero crossing rate
#     # magnitude spectrum ?
#     # band energy ratio
#     # spectral centroid
#     # spectral bandwidth
