# %%
import pandas as pd

# %%
import numpy as np

# %%
filename = 'C:/Users/Asus/Documents/Data Sci team/Datathon.csv'

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("C:/Users/Asus/Documents/Data Sci team/Datathon.csv") 
# Preview the first 5 lines of the loaded data 
data
# Out:
#              Timestamp                  Email Address       Team Name  \
# 0   9/22/2020 20:58:46     kaisar.dauletbek@nu.edu.kz              KD
# 1   9/22/2020 21:04:13     serik.zhilibayev@nu.edu.kz          Единал
# 2   9/22/2020 21:09:30  yermukhamet.medetov@nu.edu.kz              YT
# 3   9/22/2020 21:20:49       kuat.madeniyet@nu.edu.kz            DLWP
# 4   9/22/2020 21:41:58       beket.myrzanov@nu.edu.kz  Beket Myrzanov
# ..                 ...                            ...             ...
# 77  10/2/2020 17:47:44             agerbolt@nu.edu.kz   Melted Chrome
# 78  10/2/2020 19:44:20       mukhit.yelemes@nu.edu.kz            MUHA
# 79  10/2/2020 20:08:25       timur.okhassov@nu.edu.kz           Timur
# 80  10/2/2020 21:25:30    islambek.temirbek@nu.edu.kz       ITemirbek
# 81  10/2/2020 21:32:12       anuar.idrissov@nu.edu.kz        Idrissov
#
#     Number of the team members      Name     Surname  Gender year of study  \
# ...

# %%
data['year of study']
# Out:
# 0               2
# 1               2
# 2             NaN
# 3     Alumni 2020
# 4               2
#          ...
# 77    Alumni 2020
# 78              1
# 79              4
# 80    Alumni 2020
# 81              1
# Name: year of study, Length: 82, dtype: object

# %%
majorname1=data['Major, Year of Study']

# %%
yearofstudy2=data['2nd participant Year of Study']

# %%
data.columns = data.columns.str.replace("'"," ")

# %%
data
# Out:
#              Timestamp                  Email Address       Team Name  \
# 0   9/22/2020 20:58:46     kaisar.dauletbek@nu.edu.kz              KD
# 1   9/22/2020 21:04:13     serik.zhilibayev@nu.edu.kz          Единал
# 2   9/22/2020 21:09:30  yermukhamet.medetov@nu.edu.kz              YT
# 3   9/22/2020 21:20:49       kuat.madeniyet@nu.edu.kz            DLWP
# 4   9/22/2020 21:41:58       beket.myrzanov@nu.edu.kz  Beket Myrzanov
# ..                 ...                            ...             ...
# 77  10/2/2020 17:47:44             agerbolt@nu.edu.kz   Melted Chrome
# 78  10/2/2020 19:44:20       mukhit.yelemes@nu.edu.kz            MUHA
# 79  10/2/2020 20:08:25       timur.okhassov@nu.edu.kz           Timur
# 80  10/2/2020 21:25:30    islambek.temirbek@nu.edu.kz       ITemirbek
# 81  10/2/2020 21:32:12       anuar.idrissov@nu.edu.kz        Idrissov
#
#     Number of the team members      Name     Surname  Gender year of study  \
# ...

# %%
majorname2=data['2nd participant s Major, Year of Study']

# %%
majorname2=majorname2.dropna()

# %%
majorname1=majorname1.dropna()

# %%
len(majorname1)
# Out:
# 35

# %%
len(majorname2)
# Out:
# 46

# %%
for col in data.columns:
    print(col)
# Out:
# Timestamp
# Email Address
# Team Name
# Number of the team members
# Name
# Surname
# Gender
# year of study
# Major, Year of Study
# Email address (be attentive, all further information will be sent to this email address)
# Phone Number
# Months/Years of Experience in Data Science
#  Name
# Surname.1
# Gender.1
# year of study.1
# Major, Year of Study.1
# Months/Years of Experience in Data Science.1
# 2nd participant s Name
# 2nd participant s Surname
# 2nd participant Year of Study
# 2nd participant s Major, Year of Study
# 2nd participant s Gender
# 2nd participant s Months/Years of Experience in Data Science
# Email address (be attentive, all further information will be sent to this email address) .1
# Phone Number.1

# %%
data['Major, Year of Study.1'].dropna()
# Out:
# 2                          Applied math MSc
# 5                                  Robotics
# 9                                      Math
# 10                                    SEDS
# 11                                     Math
# 14                                     Math
# 15                                Economics
# 16                 Engineering Management M
# 17                                     Math
# 18                     Chemical Engineering
# 19                         Computer Science
# 20                         Computer Science
# 21                                 Robotics
# 22                         Computer Science
# 23                         Computer Science
# 24                         Computer Science
# 25                      Computers Science M
# 27                         ECE, 1 year Grad
# 28                           Data Science M
# 29                           Data Science M
# 30                           Data Science M
# ...

# %%
data['Major, Year of Study.1'].dropna()
# Out:
# 2                          Applied math MSc
# 5                                  Robotics
# 9                                      Math
# 10                                    SEDS
# 11                                     Math
# 14                                     Math
# 15                                Economics
# 16                 Engineering Management M
# 17                                     Math
# 18                     Chemical Engineering
# 19                         Computer Science
# 20                         Computer Science
# 21                                 Robotics
# 22                         Computer Science
# 23                         Computer Science
# 24                         Computer Science
# 25                      Computers Science M
# 27                         ECE, 1 year Grad
# 28                           Data Science M
# 29                           Data Science M
# 30                           Data Science M
# ...

# %%
len(data['2nd participant s Major, Year of Study'].dropna())
# Out:
# 46

# %%
len(data['2nd participant Year of Study'].dropna())
# Out:
# 37

# %%
len(data['Email address (be attentive, all further information will be sent to this email address) '].dropna())
# Out:
# 36

# %%
len(data['Email address (be attentive, all further information will be sent to this email address) .1'].dropna())
# Out:
# 46

# %%
email= pd.read_csv("C:/Users/Asus/Documents/NU SALTA/agri_dataset_2020/email.csv", delimiter='\t')

# %%
email
# Out:
#                            email
# 0     kaisar.dauletbek@nu.edu.kz
# 1     serik.zhilibayev@nu.edu.kz
# 2       kuat.madeniyet@nu.edu.kz
# 3            beket0101@gmail.com
# 4      mohammad.bayat@nu.edu.kz
# ..                           ...
# 77   shynggys.saparbek@nu.edu.kz
# 78       amina.shaikym@nu.edu.kz
# 79         sherkhan.NU@yandex.ru
# 80  bakdauren.narbayev@nu.edu.kz
# 81            kasymmkk@gmail.com
#
# [82 rows x 1 columns]

# %%
uniqueValues = email['email'].unique()

# %%
len(uniqueValues)
# Out:
# 79

# %%
uniqueValues
# Out:
# array(['kaisar.dauletbek@nu.edu.kz', 'serik.zhilibayev@nu.edu.kz',
#        'kuat.madeniyet@nu.edu.kz', 'beket0101@gmail.com',
#        'mohammad.bayat@nu.edu.kz ', 'nazym.shakirkhozha@nu.edu.kz',
#        'ulugbek.alibekov@nu.edu.kz', 'farkhad.kuanyshkereyev@nu.edu.kz',
#        'alfarabi.nagashbayev@nu.edu.kz', 'makar.lezhnikov@nu.edu.kz',
#        'aidynbek.tussipzhan@nu.edu.kz', 'arman.tarpanov@nu.edu.kz',
#        'abilkair.bolatbayev@nu.edu.kz', 'serik.almakhan@nu.edu.kz',
#        'olzhas.sutemgenov@nu.edu.kz', 'ulanbek.kurmaniyazov@nu.edu.kz',
#        'aidynkadyr@gmail.com', 'zhanibek.darimbekov@nu.edu.kz',
#        'meiirlan.suiirkhanov@nu.edu.kz', 'nurbolat.bazarbek@nu.edu.kz',
#        'alisher.amantay@nu.edu.kz', 'gulnur.maulenova@nu.edu.kz',
#        'alibi.kaiyr@nu.edu.kz', 'vladislav.yarovenko@nu.edu.kz',
#        'timur.rakhimzhan@gmail.com', 'milka3341@gmail.com',
#        'rustem.turtayev@nu.edu.kz', 'damilya.saduakhas@nu.edu.kz',
# ...

# %%
uniqueValues = email.nunique()

# %%
uniqueValues
# Out:
# email    79
# dtype: int64

# %%
frequency = email['email'].value_counts()

# %%
frequency
# Out:
# nazym.shakirkhozha@nu.edu.kz        2
# farkhad.kuanyshkereyev@nu.edu.kz    2
# assem.kussainova@nu.edu.kz          2
# kaisar.dauletbek@nu.edu.kz          1
# vladislav.yarovenko@nu.edu.kz       1
#                                    ..
# ruslan.shaimerdenuly@nu.edu.kz      1
# yerlan.amanzholov@nu.edu.kz         1
# albina.li@nu.edu.kz                 1
# beket0101@gmail.com                 1
# rustem.turtayev@nu.edu.kz           1
# Name: email, Length: 79, dtype: int64

# %%
major= pd.read_csv("C:/Users/Asus/Documents/NU SALTA/agri_dataset_2020/major.csv", delimiter='\t')

# %%
major
# Out:
#                          Applied math MSc
# 0                                Robotics
# 1                                    Math
# 2                                   SEDS
# 3                                    Math
# 4                                    Math
# ..                                    ...
# 86                       Computer Science
# 87                       Computer Science
# 88                       Computer Science
# 89                       Computer Science
# 90  Electrical and Electronic Engineering
#
# [91 rows x 1 columns]

# %%
datathon= pd.read_csv('C:/Users/Asus/Documents/DataSci/datathon1.csv', header=None)

# %%
datathon
# Out:
#                                                     0
# 0   email;major;Degree;YEAR OF STUDY;number of tea...
# 1   kaisar.dauletbek@nu.edu.kz;Language Linguistic...
# 2      serik.zhilibayev@nu.edu.kz;Data Science ;M;4;1
# 3   kuat.madeniyet@nu.edu.kz;Electrical and Comput...
# 4          beket0101@gmail.com;Computer Science;B;1;1
# ..                                                ...
# 78  bakdauren.narbayev@nu.edu.kz;Computer Science;...
# 79  kasymmkk@gmail.com;Electrical and Electronic E...
# 80                   ainat.abylgaziyeva@nu.edu.kz;;;;
# 81                       anuar.syzdykov@nu.edu.kz;;;;
# 82                         maracrasavap@gmail.com;;;;
#
# [83 rows x 1 columns]

# %%
data['2nd participant Year of Study'].dropna()
