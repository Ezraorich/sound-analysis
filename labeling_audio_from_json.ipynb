# %%
import pandas as pd

# %%
fg = pd.read_csv("D:/COVID_COUGH_SOUNDS/sounds the last/aug_our_chunk_coughvid.csv")

# %%
dfff = pd.read_json('D:/COVID_COUGH_SOUNDS/records_1635252425073.json')

# %%
fg
# Out:
#            filename  chroma_stft          rmse  spectral_centroid  \
# 0       100_covid_0     0.577523  2.062868e-04        3808.120156
# 1       100_covid_1     0.174216  1.090650e-05        2298.474516
# 2      100_covid_10     0.031124  4.334883e-07         559.643581
# 3      100_covid_11     0.000000  0.000000e+00           0.000000
# 4      100_covid_12     0.000000  0.000000e+00           0.000000
# ...             ...          ...           ...                ...
# 46788     9_covid_5     0.382865  3.663293e-02        3257.466566
# 46789     9_covid_6     0.324661  2.902291e-02        3728.392852
# 46790     9_covid_7     0.342198  4.267326e-02        3019.924102
# 46791     9_covid_8     0.272599  1.919693e-02        2642.740542
# 46792     9_covid_9     0.265181  3.615819e-03        2589.682523
#
#        spectral_bandwidth      rolloff  zero_crossing_rate        mfcc1  \
# 0             3204.348685  7613.944869            0.143810  -908.061096
# ...

# %%
#dfff
fg['file'] = fg['filename'] 
fg
# Out:
#            filename  chroma_stft          rmse  spectral_centroid  \
# 0       100_covid_0     0.577523  2.062868e-04        3808.120156
# 1       100_covid_1     0.174216  1.090650e-05        2298.474516
# 2      100_covid_10     0.031124  4.334883e-07         559.643581
# 3      100_covid_11     0.000000  0.000000e+00           0.000000
# 4      100_covid_12     0.000000  0.000000e+00           0.000000
# ...             ...          ...           ...                ...
# 46788     9_covid_5     0.382865  3.663293e-02        3257.466566
# 46789     9_covid_6     0.324661  2.902291e-02        3728.392852
# 46790     9_covid_7     0.342198  4.267326e-02        3019.924102
# 46791     9_covid_8     0.272599  1.919693e-02        2642.740542
# 46792     9_covid_9     0.265181  3.615819e-03        2589.682523
#
#        spectral_bandwidth      rolloff  zero_crossing_rate        mfcc1  \
# 0             3204.348685  7613.944869            0.143810  -908.061096
# ...

# %%
dfff
# Out:
#                         id              time             country    status  \
# 0     CmyLKNKuklivfSGGWxe5  2021-10-25 20:37               India   Pending
# 1     ZBy3Iz1tHQsisRtEAfJV  2021-10-25 07:50  Russian Federation   Pending
# 2     QS9de9RU30T6jmnzsWz7  2021-10-25 05:01         Switzerland   Pending
# 3     afvJD8zkoAuTJFRG1wDT  2021-10-25 04:59         Switzerland   Pending
# 4     YWx49tPmdW94IEb4FqL6  2021-10-24 17:42              Poland   Pending
# ...                    ...               ...                 ...       ...
# 1004  T1tcNI8R4aUB3wgPQnWK  2020-04-18 10:35          Kazakhstan  Accepted
# 1005  xVgrzhNlDGiQIZXff5Vs  2020-04-18 10:35          Kazakhstan  Accepted
# 1006  q4NsmS5Ylhs2CBNAeS6k  2020-04-16 13:12       United States  Accepted
# 1007  FtLgJX8Tuy2LsbXuOlNk  2020-04-14 07:48      United Kingdom  Accepted
# 1008  f2KB0qT4KO1l6y3DPRRT  2020-04-13 15:58          Kazakhstan  Accepted
#
#       age  duration        city           fileName  accepted  \
# ...

# %%
dfff['fileName'] = dfff['fileName'].replace({'.aac':''}, regex=True)
dfff['fileName'] = dfff['fileName'].replace({'.wav':''}, regex=True)

# %%
fg[['filename','newcol']]= fg['filename'].str.split('_', 1, expand=True)

# %%
fg
# Out:
#       filename  chroma_stft          rmse  spectral_centroid  \
# 0          100     0.577523  2.062868e-04        3808.120156
# 1          100     0.174216  1.090650e-05        2298.474516
# 2          100     0.031124  4.334883e-07         559.643581
# 3          100     0.000000  0.000000e+00           0.000000
# 4          100     0.000000  0.000000e+00           0.000000
# ...        ...          ...           ...                ...
# 46788        9     0.382865  3.663293e-02        3257.466566
# 46789        9     0.324661  2.902291e-02        3728.392852
# 46790        9     0.342198  4.267326e-02        3019.924102
# 46791        9     0.272599  1.919693e-02        2642.740542
# 46792        9     0.265181  3.615819e-03        2589.682523
#
#        spectral_bandwidth      rolloff  zero_crossing_rate        mfcc1  \
# 0             3204.348685  7613.944869            0.143810  -908.061096
# 1             1512.636955  3951.587469            0.124123 -1071.409790
# ...

# %%
dfff = dfff.rename({'fileName': 'filename'}, axis=1)

# %%
result = pd.merge(dfff, fg, how="inner", on=["filename"])

# %%
result
# Out:
#                          id              time     country    status  age  \
# 0      CmyLKNKuklivfSGGWxe5  2021-10-25 20:37       India   Pending   31
# 1      CmyLKNKuklivfSGGWxe5  2021-10-25 20:37       India   Pending   31
# 2      CmyLKNKuklivfSGGWxe5  2021-10-25 20:37       India   Pending   31
# 3      CmyLKNKuklivfSGGWxe5  2021-10-25 20:37       India   Pending   31
# 4      CmyLKNKuklivfSGGWxe5  2021-10-25 20:37       India   Pending   31
# ...                     ...               ...         ...       ...  ...
# 31956  f2KB0qT4KO1l6y3DPRRT  2020-04-13 15:58  Kazakhstan  Accepted   45
# 31957  f2KB0qT4KO1l6y3DPRRT  2020-04-13 15:58  Kazakhstan  Accepted   45
# 31958  f2KB0qT4KO1l6y3DPRRT  2020-04-13 15:58  Kazakhstan  Accepted   45
# 31959  f2KB0qT4KO1l6y3DPRRT  2020-04-13 15:58  Kazakhstan  Accepted   45
# 31960  f2KB0qT4KO1l6y3DPRRT  2020-04-13 15:58  Kazakhstan  Accepted   45
#
#        duration        city       filename  accepted  \
# ...

# %%
46793 -31961
# Out:
# 14832

# %%
labelsdf = result[['file','correlation']]

# %%
labelsdf['file']
# Out:
# 0              1635194173942_0
# 1              1635194173942_1
# 2              1635194173942_2
# 3              1635194173942_3
# 4              1635194173942_4
#                  ...
# 31956    1586793423518_speed_5
# 31957    1586793423518_speed_6
# 31958    1586793423518_speed_7
# 31959    1586793423518_speed_8
# 31960    1586793423518_speed_9
# Name: file, Length: 31961, dtype: object

# %%
labelsdf.file = labelsdf.file.apply(lambda x:x+'.wav')
#= data.Col1.apply(lambda x: x + '_'*(max_length - len(x)))
# Out:
# C:\Users\salta\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
labelsdf.file
# Out:
# 0              1635194173942_0.wav
# 1              1635194173942_1.wav
# 2              1635194173942_2.wav
# 3              1635194173942_3.wav
# 4              1635194173942_4.wav
#                    ...
# 31956    1586793423518_speed_5.wav
# 31957    1586793423518_speed_6.wav
# 31958    1586793423518_speed_7.wav
# 31959    1586793423518_speed_8.wav
# 31960    1586793423518_speed_9.wav
# Name: file, Length: 31961, dtype: object

# %%
labelsdf.to_csv('D:/COVID_COUGH_SOUNDS/DATASET_FINAL/WEBAPP+COUGHVID_CHUNKS_50_OVERLAP/labelsofaug.csv')

# %%
#labelsdf['after'] = labelsdf["file"] + [".wav" * i for i in labelsdf["file"]]

# %%
#labelsdf['file'] = dfff['file'].replace({'.wav':''}, regex=True)

# %%
labelsdf['correlation'].value_counts()
# Out:
# Other                   14173
# COVID-19                 7608
# Allergies                3920
# Asthma                   3776
# Pneumonia/Bronchitis     2484
# Name: correlation, dtype: int64

# %%
allergies = labelsdf[labelsdf['correlation']=='Pneumonia/Bronchitis']

# %%
allergies['file']
# Out:
# 604            1630617115433_0.wav
# 605            1630617115433_1.wav
# 606           1630617115433_10.wav
# 607           1630617115433_11.wav
# 608           1630617115433_12.wav
#                    ...
# 30216    1593170386108_speed_5.wav
# 30217    1593170386108_speed_6.wav
# 30218    1593170386108_speed_7.wav
# 30219    1593170386108_speed_8.wav
# 30220    1593170386108_speed_9.wav
# Name: file, Length: 2484, dtype: object

# %%
from glob import glob
import shutil

DATA_DIR = 'D:/COVID_COUGH_SOUNDS/CHUNKS_WITH_OVERLAP50/'
filenames =glob(DATA_DIR + '/*.wav')
destination  = 'D:/COVID_COUGH_SOUNDS/DATASET_FINAL/WEBAPP+COUGHVID_CHUNKS_50_OVERLAP/pneumonia/'

for i in allergies['file']:
    source = DATA_DIR+i
    shutil.copy(source, destination)
    #print(fileeee)
