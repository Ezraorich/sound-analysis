# %%
## MFCC feature extraction of 50 ms audio chunks with 50% overlap. Training on SVM, XGBoost, ANN
# 1. with our dataset(1:1, 1:2, 1:3)
# 2. with augmented our dataset (1:1, 1:2, 1:3)
# 3. ESA+COSWARA+ou dataset (1:1, 1:2, 1:3)

# %%
import pandas as pd
new= pd.read_json('D:/COVID_COUGH_SOUNDS/new_rec.json')

# %%
new
# Out:
#                       id              time         country    status  age  \
# 0   f2KB0qT4KO1l6y3DPRRT  2020-04-13 15:58      Kazakhstan  Accepted   45
# 1   FtLgJX8Tuy2LsbXuOlNk  2020-04-14 07:48  United Kingdom  Accepted   24
# 2   q4NsmS5Ylhs2CBNAeS6k  2020-04-16 13:12   United States  Accepted   36
# 3   xVgrzhNlDGiQIZXff5Vs  2020-04-18 10:35      Kazakhstan  Accepted   55
# 4   T1tcNI8R4aUB3wgPQnWK  2020-04-18 10:35      Kazakhstan  Accepted   55
# ..                   ...               ...             ...       ...  ...
# 95  uq6BfQN62ZNrWGvmkeLz  2020-09-08 06:52      Kazakhstan  Accepted   27
# 96  G4bZqwUvahu2vkPvYeUG  2020-09-09 16:23  United Kingdom  Accepted   13
# 97  mrOCtmx94Q6G9nXrOY0r  2020-09-12 15:53     New Zealand  Accepted   28
# 98  TlFX42s6u8TvcuS8yD3o  2020-09-13 06:33   United States  Accepted   30
# 99  Yt91CUimTZ3fUvJa0g8p  2020-09-13 13:58      Kazakhstan  Accepted   33
#
#     duration        city           fileName  accepted  \
# ...

# %%
old = pd.read_json('C:/Users/salta/Documents/COVID19/records_1611742128218.json')

# %%
old
# Out:
#                        id              time             country    status  \
# 0    KQlY5NefNw1QrvnECUzR  2021-01-09 05:39         Netherlands   Pending
# 1    SmA1FXu1e4LDxPr1WzAF  2021-01-05 01:28           Australia   Pending
# 2    pUGrCxUGxJYkmSJrlWQf  2020-12-10 10:23               Spain   Pending
# 3    bnwHWmq1pbNng3FUdw5b  2020-12-09 19:56               Spain   Pending
# 4    jUfa4DToJmLXsGgQciE8  2020-12-09 15:40               Spain   Pending
# ..                    ...               ...                 ...       ...
# 506  xVgrzhNlDGiQIZXff5Vs  2020-04-18 10:35          Kazakhstan   Pending
# 507  q4NsmS5Ylhs2CBNAeS6k  2020-04-16 13:12       United States   Pending
# 508  FtLgJX8Tuy2LsbXuOlNk  2020-04-14 07:48      United Kingdom   Pending
# 509  f2KB0qT4KO1l6y3DPRRT  2020-04-13 15:58          Kazakhstan  Accepted
# 510  fh0ZYHzmwX8GD0k05RLE  2021-01-25 02:22  Russian Federation   Pending
#
#      age  duration          city           fileName  \
# ...

# %%
2021-01-25 02:22
2021-01-09 05:39

# %%
from pydub import AudioSegment

# %%
import os
head, tail = os.path.split("D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1605301692843.aac")
print(head)
print(tail)
# Out:
# D:\
# COVID_COUGH_SOUNDSac_cough_analyzer_web_appacp5301692843.aac

# %%
import os
base=os.path.basename('D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1605322668189.aac')
#base
#os.path.splitext(base)

os.path.splitext(base)[0]
# Out:
# 'COVID_COUGH_SOUNDS\x07ac_cough_analyzer_web_app\x07acp5322668189'

# %%
directory_in_str = 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/aac'
pathlist = Path(directory_in_str).glob('**/*.aac')
for i in pathlist:
    #base=os.path.basename(i)
    #a = os.path.splitext(base)[0]
    #print(a)
    print(i)
# Out:
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1586793423518.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1586850463146.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587042586994.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587206042393.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587206113525.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587211554005.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587222464780.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587242290008.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587275861922.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587278937951.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587902161443.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587966224047.aac
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\aac\1587966692880.aac
# ...

# %%
from pathlib import Path

try:
    directory_in_str = 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/aac'
    new_dir  = 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wav/'
    pathlist = Path(directory_in_str).glob('**/*.aac')
    for i in pathlist:
        path_in_str = str(i)
    #print(path_in_str)
        base=os.path.basename(i)
        a = os.path.splitext(base)[0]
    
        data, samplerate = sf.read(path_in_str)
        sf.write(new_dir+str(a)+'.wav', data, samplerate)
except RuntimeError:
    pass

# %%
import librosa

# %%
files[:10]
# Out:
# ['D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1586793423518.aac',
#  'D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1586850463146.aac',
#  'D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1587042586994.aac',
#  'D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1587206042393.aac',
#  'D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1587206113525.aac',
#  'D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1587211554005.aac',
#  'D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1587222464780.aac',
#  'D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1587242290008.aac',
#  'D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1587275861922.aac',
#  'D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\aac\\1587278937951.aac']

# %%
y, sr = librosa.load(files[1])
sf.write('D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\file_trim_1.wav', y, sr, format='wav')
    #librosa.output.write_wav('D:\\COVID_COUGH_SOUNDS\\aac_cough_analyzer_web_app\\file_trim_'+str(i)+'.wav', y, sr)

# %%
directory_in_str = 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/aac'
new_dir  = 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wav/'
pathlist = Path(directory_in_str).glob('**/*.aac')
for i in pathlist:
    path_in_str = str(i)
    #print(path_in_str)
    base=os.path.basename(i)
    a = os.path.splitext(base)[0]
    
    y, sr = librosa.load(path_in_str)
    
    sf.write(new_dir+str(a)+'.wav', y, sr, format ='wav')
# Out:
# C:\Users\salta\anaconda3\lib\site-packages\librosa\core\audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# ~\anaconda3\lib\site-packages\soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ...
