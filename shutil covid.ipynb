# %%
import pandas as pd

# %%
sd = pd.read_csv('D:/COVID_COUGH_SOUNDS/MFCC/train/labeled_50overlap_1second_mfcc_features.csv')

# %%
dfff = pd.read_json('D:/COVID_COUGH_SOUNDS/records_1635252425073.json')

# %%
dfff = dfff.rename({'fileName': 'filename'}, axis=1)
dfff['filename'] = dfff['filename'].replace({'.aac':''}, regex=True)
dfff['filename'] = dfff['filename'].replace({'.wav':''}, regex=True)

# %%
dfff
# Out:
#                         id              time             country    status  \
# 0     CmyLKNKuklivfSGGWxe5  2021-10-25 20:37               India   Pending
# 1     ZBy3Iz1tHQsisRtEAfJV  2021-10-25 07:50  Russian Federation   Pending
# 2     QS9de9RU30T6jmnzsWz7  2021-10-25 05:01         Switzerland   Pending
# 3     afvJD8zkoAuTJFRG1wDT  2021-10-25 04:59         Switzerland   Pending
# 4     YWx49tPmdW94IEb4FqL6  2021-10-24 17:42              Poland   Pending
# ...                    ...               ...                 ...       ...
# 1004  T1tcNI8R4aUB3wgPQnWK  2020-04-18 10:35          Kazakhstan  Accepted
# 1005  xVgrzhNlDGiQIZXff5Vs  2020-04-18 10:35          Kazakhstan  Accepted
# 1006  q4NsmS5Ylhs2CBNAeS6k  2020-04-16 13:12       United States  Accepted
# 1007  FtLgJX8Tuy2LsbXuOlNk  2020-04-14 07:48      United Kingdom  Accepted
# 1008  f2KB0qT4KO1l6y3DPRRT  2020-04-13 15:58          Kazakhstan  Accepted
#
#       age  duration        city       filename  accepted  \
# ...

# %%
dfff = dfff.rename({'fileName': 'filename'}, axis=1)

# %%
new = dfff[['filename', 'correlation']]

# %%
new['correlation'].value_counts()
# Out:
# I do not  have a diagnosis    358
# Other                         332
# COVID-19                      129
# Asthma                         74
# Allergies                      63
# Pneumonia/Bronchitis           33
# Cardio                         10
# Cancer                          8
# Tuberculosis                    2
# Name: correlation, dtype: int64

# %%
filen = new[new['correlation']=='COVID-19']

# %%
pneu = list(filen['filename'])

# %%
dir_name='/home/me/dev/my_reports/'
base_filename='daily_report.pdf'
os.path.join(dir_name, base_filename)
# Out:
# '/home/me/dev/my_reports/daily_report.pdf'

# %%
import os
dir_name  = 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wavlibrosa/'
base_filename = '1635024008549.wav'
a = os.path.join(dir_name, base_filename)
a
# Out:
# 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wavlibrosa/1635024008549.wav'

# %%
pneu
# Out:
# ['1633766649204',
#  '1632578745338',
#  '1632487073873',
#  '1631546662031',
#  '1631212948737',
#  '1630765053621',
#  '1630589609083',
#  '1630448677713',
#  '1630448442061',
#  '1629490127741',
#  '1628723051297',
#  '1627829794151',
#  '1627200972033',
#  '1626951364527',
#  '1626915462251',
#  '1626915237278',
#  '1626914868884',
#  '1626914537734',
#  '1626499838757',
#  '1626499657893',
#  '1626365669436',
#  '1626338641890',
#  '1626311843564',
#  '1626284464645',
#  '1626163529973',
#  '1625827364960',
#  '1625760174640',
#  '1625737606183',
#  '1624658903144',
#  '1623297567134',
#  '1623256252868',
#  '1622795857496',
#  '1622637039482',
#  '1622636752883',
#  '1622566037145',
#  '1622236161760',
#  '1622202294382',
#  '1622195240349',
#  '1621275913841',
#  '1620286268903',
#  '1619705994772',
#  '1619207540077',
#  '1618081734354',
#  '1617503043586',
#  '1617312152777',
#  '1617128653293',
#  '1616171600979',
#  '1615971216458',
#  '1614311634541',
#  '1614059653418',
# ...

# %%
import os
dir_name  = "D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wavlibrosa"
s = []
for i in pneu:
    a = os.path.join(dir_name,i)
    s.append(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-db4de15d0a50> in <module>
#       3 s = []
#       4 for i in pneu:
# ----> 5     a = os.path.join(dir_name,+'/', i)
#       6     s.append(a)
#       7
#
# TypeError: bad operand type for unary +: 'str'

# %%
dir_name = "D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wavlibrosa"
base_filename = '1625737606183'
filename_suffix ='wav'
os.path.join(dir_name, base_filename + "." + filename_suffix)
# Out:
# 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wavlibrosa\\1625737606183.wav'

# %%
pneu
# Out:
# []

# %%
dir_name  = "D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wavlibrosa/"
filename_suffix ='wav'
for f in pneu:
    a = os.path.join(dir_name, f + "." + filename_suffix)
    
    shutil.copy(a, 'D:/COVID_COUGH_SOUNDS/sounds the last/covid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-149-cc32ba40c31d> in <module>
#       4     a = os.path.join(dir_name, f + "." + filename_suffix)
#       5
# ----> 6     shutil.copy(a, 'D:/COVID_COUGH_SOUNDS/sounds the last/covid')
#
# ~\anaconda3\lib\shutil.py in copy(src, dst, follow_symlinks)
#     416     if os.path.isdir(dst):
#     417         dst = os.path.join(dst, os.path.basename(src))
# --> 418     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     419     copymode(src, dst, follow_symlinks=follow_symlinks)
#     420     return dst
#
# ~\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     262         os.symlink(os.readlink(src), dst)
#     263     else:
# --> 264         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     265             # macOS
#     266             if _HAS_FCOPYFILE:
#
# ...

# %%
import shutil, os

try:
    for f in pneu:
        a = os.path.join(dir_name, f + "." + filename_suffix)
    
        shutil.copy(a, 'D:/COVID_COUGH_SOUNDS/sounds the last/pneumonia')
except:
    pass
    #print(f)

# %%
from pathlib import Path
directory_in_str = 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wavlibrosa/'
pathlist = Path(directory_in_str).glob('**/*.wav')
for i in pathlist:
    import shutil, os
#files = ['file1.txt', 'file2.txt', 'file3.txt']
for f in asthma:
    f.
    shutil.copy(f, 'dest_folder')
    print(i)
# Out:
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1586793423518.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587042586994.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587206042393.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587206113525.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587211554005.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587222464780.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587242290008.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587275861922.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587278937951.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587902161443.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587966224047.wav
# D:\COVID_COUGH_SOUNDS\aac_cough_analyzer_web_app\wavlibrosa\1587966692880.wav
# ...

# %%
type(new['filename'][1])
# Out:
# str

# %%
type(sd['filename'][1])
# Out:
# numpy.int64

# %%
#df = sd.astype({"filename": str})

# %%
new['filename']=new['filename'].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-45dcd19c7636> in <module>
# ----> 1 new['filename']=new['filename'].astype(np.int64)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5804         else:
#    5805             # else, only a single dtype is given
# -> 5806             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807             return self._constructor(new_data).__finalize__(self, method="astype")
#    5808
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     412
#     413     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 414         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     415
#     416     def convert(
#
# ...

# %%
import numpy as np

# %%
#result = pd.merge(df, sd, how="inner", on=["filename"])
new['filename']=new['filename'].astype(np.int64)
sd['filename']=sd['filename'].astype(np.int64)
new.merge(sd, how='inner', on='filename')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-8a9bee9510f1> in <module>
#       1 #result = pd.merge(df, sd, how="inner", on=["filename"])
# ----> 2 new['filename']=new['filename'].astype(np.int64)
#       3 sd['filename']=sd['filename'].astype(np.int64)
#       4 new.merge(sd, how='inner', on='filename')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5804         else:
#    5805             # else, only a single dtype is given
# -> 5806             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807             return self._constructor(new_data).__finalize__(self, method="astype")
#    5808
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     412
# ...

# %%
df
# Out:
#            filename  chroma_stft      rmse  spectral_centroid  \
# 0     1586793423518     0.518146  0.006942        1429.256245
# 1     1586793423518     0.495280  0.034485        2157.372433
# 2     1586793423518     0.446874  0.036917        2905.736284
# 3     1586793423518     0.465129  0.053680        2636.513642
# 4     1586793423518     0.513032  0.027794        2382.390945
# ...             ...          ...       ...                ...
# 7986  1635194173942     0.562462  0.087709         936.160425
# 7987  1635194173942     0.582610  0.094756         854.049971
# 7988  1635194173942     0.589856  0.026031         833.515807
# 7989  1635194173942     0.530176  0.051015         888.532884
# 7990  1635194173942     0.513063  0.059889         872.706232
#
#       spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0            1946.914411  3411.299827            0.041226 -453.064362
# 1            2208.689401  4934.039862            0.101540 -311.985443
# ...

# %%
new
# Out:
#            filename                 correlation
# 0     1635194173942                   Allergies
# 1     1635148118720  I do not  have a diagnosis
# 2     1635137994769                       Other
# 3     1635137806431  I do not  have a diagnosis
# 4     1635097220571  I do not  have a diagnosis
# ...             ...                         ...
# 1004  1587206113525                       Other
# 1005  1587206042393                       Other
# 1006  1587042586994                      Asthma
# 1007  1586850463146                      Cardio
# 1008  1586793423518                       Other
#
# [1009 rows x 2 columns]
