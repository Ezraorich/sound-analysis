# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
import librosa
import csv
import os
from glob import glob

# %% [markdown]
# root = 'D:/COVID_COUGH_SOUNDS/1second_chunks_458/NON_AUGMENTED_1_SEC_CHUNKS_NO_OVERLAP/train'
# test_filenames= []
# for path, subdirs, files in os.walk(root):
#     for name in files:
#         #print(os.path.join(path, name))
#         test_filenames.append(os.path.join(path, name))

# %%
#DATA_DIR='D:/COVID_COUGH_SOUNDS/DATASET_FINAL/WEBAPP+COUGHVID_CHUNKS_50_OVERLAP/allergies/'
#filenames =glob(DATA_DIR + '/*.wav')

# %%
def load_audio_file(file_path):
    input_length = 16000
    data = librosa.core.load(file_path)[0] #, sr=16000
    return data

# %%
def get_data_files():
    # we will be leaving some files out, on purpose. Do not change this function!
    return [os.path.join(DATA_DIR, x) for x in sorted(os.listdir(DATA_DIR)) ]

# %%
def get_sound_id_from_file_path(file_path):
    a = file_path.split('\\')[-2:]
    return a

# %% [markdown]
# print(test_filenames[1])
# correlation, key = get_sound_id_from_file_path(test_filenames[1])
# print(correlation)
# print(key)

# %%
def extractWavFeatures(soundFilesFolder, csvFileName):
    test_filenames= []
    for path, subdirs, files in os.walk(soundFilesFolder):
        for name in files:
        #print(os.path.join(path, name))
            test_filenames.append(os.path.join(path, name))
        
    print("The features of the files in the folder "+soundFilesFolder+" will be saved to "+csvFileName)
    header = 'key correlation chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'
    for i in range(1, 21):
        header += f' mfcc{i}'
    #header += ' label'
    header = header.split()
    print('CSV Header: ', header)
    
    file = open(csvFileName, 'w', newline='')
    #with file:
    writer = csv.writer(file)
    writer.writerow(header)
    
    for i in test_filenames:
        correlation, key  = get_sound_id_from_file_path(i)
        y, sr = librosa.load(i, mono=True, duration=30)
        
        # remove leading and trailing silence
        
        y, index = librosa.effects.trim(y)
        
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        rmse = librosa.feature.rms(y=y)
        spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        
        to_append = f' {key} {correlation} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'
        for e in mfcc:
            to_append += f' {np.mean(e)}'
        writer.writerow(to_append.split())
    file.close()
    print("End of extractWavFeatures")

# %%
CREATE_CSV_FILES = True

# %%
TRAIN_CSV_FILE = "D:/COVID_COUGH_SOUNDS/50S_overlap_458/50msOverlap_chunks_notAUG/MFCC_train.csv"
TEST_CSV_FILE = "D:/COVID_COUGH_SOUNDS/50S_overlap_458/50msOverlap_chunks_notAUG/MFCC_test.csv"
#MORE_TRAIN_CSV_FILE = "C:/Users/Asus/Documents/COVID19/MFCC/test/more_train.csv"
#MORE_TEST_CSV_FILE = "C:/Users/Asus/Documents/COVID19/MFCC/test/more_test.csv"

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
import librosa
import csv
import os



if (CREATE_CSV_FILES == True):
    extractWavFeatures("D:/COVID_COUGH_SOUNDS/50S_overlap_458/50msOverlap_chunks_notAUG/train", TRAIN_CSV_FILE)
    extractWavFeatures("D:/COVID_COUGH_SOUNDS/50S_overlap_458/50msOverlap_chunks_notAUG/test", TEST_CSV_FILE)
    #extractWavFeatures("C:/Users/Asus/Documents/COVID19/MFCC/moreSpeakersTrain", MORE_TRAIN_CSV_FILE)
    #extractWavFeatures("C:/Users/Asus/Documents/COVID19/MFCC/moreSpeakersTest", MORE_TEST_CSV_FILE)
    print("CSV files are created")
else:
    print("CSV files creation is skipped")
# Out:
# The features of the files in the folder D:/COVID_COUGH_SOUNDS/50S_overlap_458/50msOverlap_chunks_notAUG/train will be saved to D:/COVID_COUGH_SOUNDS/50S_overlap_458/50msOverlap_chunks_notAUG/MFCC_train.csv
# CSV Header:  ['key', 'correlation', 'chroma_stft', 'rmse', 'spectral_centroid', 'spectral_bandwidth', 'rolloff', 'zero_crossing_rate', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5', 'mfcc6', 'mfcc7', 'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12', 'mfcc13', 'mfcc14', 'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19', 'mfcc20']
# C:\Users\salta\anaconda3\lib\site-packages\librosa\core\pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# C:\Users\salta\anaconda3\lib\site-packages\librosa\core\spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=1536
#   warnings.warn(
# ...

# %%
import pandas as pd
train = pd.read_csv(TRAIN_CSV_FILE)
test = pd.read_csv(TEST_CSV_FILE)

# %%
#TRAIN_CSV_FILE

# %%
train
# Out:
#                       key correlation  chroma_stft      rmse  \
# 0     1601354644605_0.wav   allergies     0.270167  0.054998
# 1     1601354644605_1.wav   allergies     0.424782  0.082105
# 2     1601354644605_2.wav   allergies     0.575571  0.042768
# 3     1601354644605_3.wav   allergies     0.617131  0.011907
# 4     1601354644605_4.wav   allergies     0.563952  0.070892
# ...                   ...         ...          ...       ...
# 6303  1630617115433_5.wav        pneu     0.535377  0.021156
# 6304  1630617115433_6.wav        pneu     0.532776  0.011890
# 6305  1630617115433_7.wav        pneu     0.513598  0.080894
# 6306  1630617115433_8.wav        pneu     0.515053  0.105197
# 6307  1630617115433_9.wav        pneu     0.497817  0.044262
#
#       spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0           2559.598938         2040.957029  5184.608043            0.168413
# ...

# %%
test
# Out:
#                       key correlation  chroma_stft      rmse  \
# 0     1591363379163_0.wav   allergies     0.524454  0.003503
# 1     1591363379163_1.wav   allergies     0.416481  0.072161
# 2     1591363379163_2.wav   allergies     0.412128  0.124396
# 3     1591363379163_3.wav   allergies     0.487229  0.100306
# 4     1591363379163_4.wav   allergies     0.556395  0.046316
# ...                   ...         ...          ...       ...
# 1677  1603942345102_5.wav        pneu     0.534623  0.045870
# 1678  1603942345102_6.wav        pneu     0.531187  0.062258
# 1679  1603942345102_7.wav        pneu     0.435711  0.096294
# 1680  1603942345102_8.wav        pneu     0.484045  0.048553
# 1681  1603942345102_9.wav        pneu     0.553253  0.006111
#
#       spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0           2159.131164         2021.219219  4512.918923            0.118974
# ...

# %%
train['correlation'].value_counts()
# Out:
# other        2815
# covid        1504
# allergies     782
# asthma        745
# pneu          462
# Name: correlation, dtype: int64

# %%
print(train['correlation'].value_counts())
# Out:
# other        2815
# covid        1504
# allergies     782
# asthma        745
# pneu          462
# Name: correlation, dtype: int64

# %%
test['correlation'].value_counts()
# Out:
# other        728
# covid        398
# asthma       199
# allergies    198
# pneu         159
# Name: correlation, dtype: int64

# %%
test['correlation'] = pd.factorize(test['correlation'])[0]
train['correlation'] = pd.factorize(train['correlation'])[0]

# %%
print(test['correlation'].value_counts())
# Out:
# 3    728
# 2    398
# 1    199
# 0    198
# 4    159
# Name: correlation, dtype: int64

# %% [markdown]
# MACHINE LEARNING

# %%
X_train = train.loc[:, train.columns!='correlation']
X_test = test.loc[:, test.columns!='correlation']
y_train  = train['correlation']
y_test = test['correlation']

# %%
del X_train['key']
del X_test['key']

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()

X_train= ms.fit_transform(X_train)
X_train = pd.DataFrame(X_train)

X_test= ms.fit_transform(X_test)
X_test = pd.DataFrame(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn import metrics
model =SVC()
model.fit (X_train, y_train)
y_pred = model.predict(X_test)
print ('SVM accuracy: ', accuracy_score (y_test, y_pred))
# Out:
# SVM accuracy:  0.3258026159334126

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPClassifier


clf = MLPClassifier(random_state=1, max_iter=2000).fit(X_train, y_train)
#clf.predict_proba(X_test)

y_pred = clf.predict(X_test)

print('MLP accuracy: ',clf.score(X_test, y_test))
# Out:
# MLP accuracy:  0.25921521997621877

# %% [markdown]
# Dechunking  and voting

# %%
test
# Out:
#                       key  correlation  chroma_stft      rmse  \
# 0     1591363379163_0.wav            0     0.524454  0.003503
# 1     1591363379163_1.wav            0     0.416481  0.072161
# 2     1591363379163_2.wav            0     0.412128  0.124396
# 3     1591363379163_3.wav            0     0.487229  0.100306
# 4     1591363379163_4.wav            0     0.556395  0.046316
# ...                   ...          ...          ...       ...
# 1677  1603942345102_5.wav            4     0.534623  0.045870
# 1678  1603942345102_6.wav            4     0.531187  0.062258
# 1679  1603942345102_7.wav            4     0.435711  0.096294
# 1680  1603942345102_8.wav            4     0.484045  0.048553
# 1681  1603942345102_9.wav            4     0.553253  0.006111
#
#       spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0           2159.131164         2021.219219  4512.918923            0.118974
# ...

# %%
true_test_values = test.loc[:, ['key','correlation']]
keys = true_test_values.key.unique()
true_test_values['predicted values'] = y_pred

# %%
from scipy.stats import mode

Mode = []
Mode2 = []

for i in keys:
    m = true_test_values[true_test_values['key']==i]['correlation'].values
    m2 = true_test_values[true_test_values['key']==i]['predicted values'].values
    
    #print(m)
    
    s = mode(m)[0]
    s2 = mode(m2)[0]
    
    Mode.append(s[0])
    Mode2.append(s2[0])

# %%
new_list = []
for i in range(len(Mode)):
    for j in range(len(Mode2)):
        if (i==j):
            if (Mode[i]==Mode2[j]):
                new_list.append(i)

# %%
#17/83
score = len(new_list)/len(Mode2)
print('Accuracy score of chunks after voting:',score)
# Out:
# Accuracy score of chunks after voting: 0.25921521997621877

# %% [markdown]
# 1 to 1 classification

# %%
train
# Out:
#                       key  correlation  chroma_stft      rmse  \
# 0     1601354644605_0.wav            0     0.270167  0.054998
# 1     1601354644605_1.wav            0     0.424782  0.082105
# 2     1601354644605_2.wav            0     0.575571  0.042768
# 3     1601354644605_3.wav            0     0.617131  0.011907
# 4     1601354644605_4.wav            0     0.563952  0.070892
# ...                   ...          ...          ...       ...
# 6303  1630617115433_5.wav            4     0.535377  0.021156
# 6304  1630617115433_6.wav            4     0.532776  0.011890
# 6305  1630617115433_7.wav            4     0.513598  0.080894
# 6306  1630617115433_8.wav            4     0.515053  0.105197
# 6307  1630617115433_9.wav            4     0.497817  0.044262
#
#       spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0           2559.598938         2040.957029  5184.608043            0.168413
# ...

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix

corr = [4, 1]
algcov = train[train.correlation.isin(corr)]
del algcov['key']

X_train = algcov.loc[:, algcov.columns != 'correlation']
y_train = algcov['correlation']

algcov_test = test[test.correlation.isin(corr)]
del algcov_test['key']

X_test = algcov_test.loc[:, algcov_test.columns != 'correlation']
y_test = algcov_test['correlation']



#from sklearn.preprocessing import MinMaxScaler
#ms = MinMaxScaler()
#X= ms.fit_transform(X)
#X = pd.DataFrame(X)

#X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=1)
clf = MLPClassifier(random_state=1, max_iter=2000, hidden_layer_sizes = 50).fit(X_train, y_train)
#clf.predict_proba(X_test)

y_pred = clf.predict(X_test)

print( clf.score(X_test, y_test))
confusion_matrix(y_test,y_pred )
# Out:
# 0.6424581005586593
# array([[115,  84],
#        [ 44, 115]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print ('Accuracy: ', accuracy_score (y_test, y_pred_rf))
#predict_cough_type = rf.predict(X_test)
#print ('Accuracy: ', accuracy_score (y_test, predict_cough_type))

from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred_rf)
# Out:
# Accuracy:  0.5418994413407822
# array([[136,  63],
#        [101,  58]], dtype=int64)

# %%
algcov_test = test[test.correlation.isin(corr)]
true_test_algcov = algcov_test.loc[:, ['key','correlation']]

true_test_algcov[['key','newcol']]= true_test_algcov['key'].str.split('_', 1, expand=True)
true_test_algcov['key'] = pd.factorize(true_test_algcov['key'])[0]

#del true_test_algcov['newcol']

keys = true_test_algcov.key.unique()
true_test_algcov['predicted values'] = y_pred
true_test_algcov['predicted rf'] = y_pred_rf

# %%
#true_test_algcov

# %%
from scipy.stats import mode

Most_common = []
Most_common2 = []
Most_common_rf = []

for i in keys:
    m = true_test_algcov[true_test_algcov['key']==i]['correlation'].values
    m2 = true_test_algcov[true_test_algcov['key']==i]['predicted values'].values
    m3 = true_test_algcov[true_test_algcov['key']==i]['predicted rf'].values
    
    #print(m)
    
    s = mode(m)[0]
    s2 = mode(m2)[0]
    s3  = mode(m3)[0]
    
    Most_common.append(s[0])
    Most_common2.append(s2[0])
    Most_common_rf.append(s3[0])

# %%
same_elements = []
same_rf = []
for i in range(len(Most_common)):
    for j in range(len(Most_common2)):
        if (i==j):
            if (Most_common[i]==Most_common2[j]):
                same_elements.append(i)
            if (Most_common[i]==Most_common_rf[j]):
                same_rf.append(i)

# %%
#17/83
score = len(same_elements)/len(Most_common2)
print('Accuracy score of chunks after MLP voting:',score)

score = len(same_rf)/len(Most_common_rf)
print('Accuracy score of chunks after RF voting:',score)
# Out:
# Accuracy score of chunks after MLP voting: 0.6818181818181818
# Accuracy score of chunks after RF voting: 0.6363636363636364

# %% [markdown]
# BALANCED DATASET

# %%
print(train['correlation'].value_counts())
# Out:
# 3    2815
# 2    1504
# 0     782
# 1     745
# 4     462
# Name: correlation, dtype: int64

# %%
new_df = train.sample(frac=1, random_state =4)

# Separate class
class_0 = new_df[new_df ['correlation'] == 0].sample(n= 782, random_state =42)
class_1 = new_df[new_df ['correlation'] == 1].sample(n= 745, random_state =42)
class_2 = new_df[new_df ['correlation'] == 2].sample(n= 782, random_state =42)
class_3 = new_df[new_df ['correlation'] == 3].sample(n= 782, random_state =42)
class_4 = new_df[new_df ['correlation'] == 4].sample(n= 462, random_state =42)

# %%
balanced_train  = pd.concat([class_0, class_1, class_2, class_3, class_4])

# %%
print(test['correlation'].value_counts())
# Out:
# 3    728
# 2    398
# 1    199
# 0    198
# 4    159
# Name: correlation, dtype: int64

# %%
new_df = test.sample(frac=1, random_state =4)

# Separate class
class_0 = new_df[new_df ['correlation'] == 0].sample(n= 198, random_state =42)
class_1 = new_df[new_df ['correlation'] == 1].sample(n= 199, random_state =42)
class_2 = new_df[new_df ['correlation'] == 2].sample(n= 199, random_state =42)
class_3 = new_df[new_df ['correlation'] == 3].sample(n= 198, random_state =42)
class_4 = new_df[new_df ['correlation'] == 4].sample(n= 159, random_state =42)

# %%
balanced_test  = pd.concat([class_0, class_1, class_2, class_3, class_4])

# %%
#balanced_test

# %%
X_train = balanced_train.loc[:, balanced_train.columns!='correlation']
X_test = balanced_test.loc[:, balanced_test.columns!='correlation']
y_train  = balanced_train['correlation']
y_test = balanced_test['correlation']

# %%
del X_train['key']
del X_test['key']

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()

X_train= ms.fit_transform(X_train)
X_train = pd.DataFrame(X_train)

X_test= ms.fit_transform(X_test)
X_test = pd.DataFrame(X_test)

# %%
model =SVC()
model.fit (X_train, y_train)
y_pred = model.predict(X_test)
print ('SVM accuracy: ', accuracy_score (y_test, y_pred))
# Out:
# SVM accuracy:  0.20356768100734524

# %%
clf = MLPClassifier(random_state=1, max_iter=2000).fit(X_train, y_train)
#clf.predict_proba(X_test)

clf.predict(X_test)

print('MLP accuracy: ',clf.score(X_test, y_test))
# Out:
# MLP accuracy:  0.17418677859391396

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix

corr = [2, 3]
algcov =balanced_train[balanced_train.correlation.isin(corr)]
del algcov['key']

X_train = algcov.loc[:, algcov.columns != 'correlation']
y_train = algcov['correlation']

algcov_test = balanced_test[balanced_test.correlation.isin(corr)]
del algcov_test['key']

X_test = algcov_test.loc[:, algcov_test.columns != 'correlation']
y_test = algcov_test['correlation']



#from sklearn.preprocessing import MinMaxScaler
#ms = MinMaxScaler()
#X= ms.fit_transform(X)
#X = pd.DataFrame(X)

#X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=1)
clf = MLPClassifier(random_state=1, max_iter=2000).fit(X_train, y_train)
#clf.predict_proba(X_test)

y_pred = clf.predict(X_test)

print( clf.score(X_test, y_test))
confusion_matrix(y_test,y_pred )
# Out:
# 0.42065491183879095
# array([[ 18, 181],
#        [ 49, 149]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print ('Accuracy: ', accuracy_score (y_test, y_pred_rf))
#predict_cough_type = rf.predict(X_test)
#print ('Accuracy: ', accuracy_score (y_test, predict_cough_type))

from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred_rf)
# Out:
# Accuracy:  0.3979848866498741
# array([[ 48, 151],
#        [ 88, 110]], dtype=int64)

# %%
algcov_test = balanced_test[balanced_test.correlation.isin(corr)]
true_test_algcov = algcov_test.loc[:, ['key','correlation']]

true_test_algcov[['key','newcol']]= true_test_algcov['key'].str.split('_', 1, expand=True)
true_test_algcov['key'] = pd.factorize(true_test_algcov['key'])[0]

#del true_test_algcov['newcol']

keys = true_test_algcov.key.unique()
true_test_algcov['predicted values'] = y_pred
true_test_algcov['predicted rf'] = y_pred_rf

# %%
from scipy.stats import mode

Most_common = []
Most_common2 = []
Most_common_rf = []

for i in keys:
    m = true_test_algcov[true_test_algcov['key']==i]['correlation'].values
    m2 = true_test_algcov[true_test_algcov['key']==i]['predicted values'].values
    m3 = true_test_algcov[true_test_algcov['key']==i]['predicted rf'].values
    
    #print(m)
    
    s = mode(m)[0]
    s2 = mode(m2)[0]
    s3  = mode(m3)[0]
    
    Most_common.append(s[0])
    Most_common2.append(s2[0])
    Most_common_rf.append(s3[0])

# %%
same_elements = []
same_rf = []
for i in range(len(Most_common)):
    for j in range(len(Most_common2)):
        if (i==j):
            if (Most_common[i]==Most_common2[j]):
                same_elements.append(i)
            if (Most_common[i]==Most_common_rf[j]):
                same_rf.append(i)

# %%
#17/83
score = len(same_elements)/len(Most_common2)
print('Accuracy score of chunks after MLP voting:',score)

score = len(same_rf)/len(Most_common_rf)
print('Accuracy score of chunks after RF voting:',score)
# Out:
# Accuracy score of chunks after MLP voting: 0.47368421052631576
# Accuracy score of chunks after RF voting: 0.38596491228070173

# %%
#dfff = pd.read_json('D:/COVID_COUGH_SOUNDS/records_1635252425073.json')

# %%
#dfff

# %%
#dfff['fileName'] = dfff['fileName'].replace({'.aac':''}, regex=True)

# %%
#dfff['correlation'].value_counts()
# Out:
# I do not  have a diagnosis    358
# Other                         332
# COVID-19                      129
# Asthma                         74
# Allergies                      63
# Pneumonia/Bronchitis           33
# Cardio                         10
# Cancer                          8
# Tuberculosis                    2
# Name: correlation, dtype: int64

# %%
#new_dir  = 'D:/COVID_COUGH_SOUNDS/MFCC/train/'
#pathlist = Path(new_dir).glob('**/*.wav')
#count=0 
#fileNames = []
#for i in pathlist:
    #path_in_str = str(i)
    #print(path_in_str)
    #base=os.path.basename(i)
    #a = os.path.splitext(base)[0]
    #fileNames.append(a)
    #count+=1
    #print(a)
#print(count)

# %%
from pathlib import Path

new_dir  = 'D:/COVID_COUGH_SOUNDS/aac_cough_analyzer_web_app/wavlibrosa/'
pathlist = Path(new_dir).glob('**/*.wav')
count=0 
fileNames = []
for i in pathlist:
    #path_in_str = str(i)
    #print(path_in_str)
    base=os.path.basename(i)
    a = os.path.splitext(base)[0]
    fileNames.append(a)
    count+=1
    #print(a)
print(count)
# Out:
# 458

# %%
fNames = pd.DataFrame(fileNames)

# %%
fNamess = fNames.rename({0: 'filenames'}, axis=1)

# %%
dfff = dfff.rename({'fileName': 'filenames'}, axis=1)

# %%
result = pd.merge(dfff, fNamess, how="inner", on=["filenames"])

# %%
result['correlation'].value_counts()
# Out:
# Other                   163
# COVID-19                118
# Asthma                   66
# Allergies                57
# Pneumonia/Bronchitis     28
# Name: correlation, dtype: int64

# %%
new = result[['filenames', 'correlation']]

# %%
new
# Out:
#          filenames           correlation
# 0    1629275449436  Pneumonia/Bronchitis
# 1    1629271883267                Asthma
# 2    1628955358117             Allergies
# 3    1628897515930             Allergies
# 4    1628897341523             Allergies
# ..             ...                   ...
# 427  1587211554005                 Other
# 428  1587206113525                 Other
# 429  1587206042393                 Other
# 430  1587042586994                Asthma
# 431  1586793423518                 Other
#
# [432 rows x 2 columns]

# %%
df
# Out:
#                   filename  chroma_stft      rmse  spectral_centroid  \
# 0      1586793423518_0.wav     0.518146  0.006942        1429.256245
# 1      1586793423518_1.wav     0.495280  0.034485        2157.372433
# 2     1586793423518_10.wav     0.446874  0.036917        2905.736284
# 3      1586793423518_2.wav     0.465129  0.053680        2636.513642
# 4      1586793423518_3.wav     0.513032  0.027794        2382.390945
# ...                    ...          ...       ...                ...
# 7986   1635194173942_4.wav     0.562462  0.087709         936.160425
# 7987   1635194173942_5.wav     0.582610  0.094756         854.049971
# 7988   1635194173942_6.wav     0.589856  0.026031         833.515807
# 7989   1635194173942_7.wav     0.530176  0.051015         888.532884
# 7990   1635194173942_8.wav     0.513063  0.059889         872.706232
#
#       spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# ...

# %%
df[['filename','newcol']]= df['filename'].str.split('_', 1, expand=True)

# %%
df = df.drop(['newcol'], axis=1)

# %%
df
# Out:
#            filename  chroma_stft      rmse  spectral_centroid  \
# 0     1586793423518     0.518146  0.006942        1429.256245
# 1     1586793423518     0.495280  0.034485        2157.372433
# 2     1586793423518     0.446874  0.036917        2905.736284
# 3     1586793423518     0.465129  0.053680        2636.513642
# 4     1586793423518     0.513032  0.027794        2382.390945
# ...             ...          ...       ...                ...
# 7986  1635194173942     0.562462  0.087709         936.160425
# 7987  1635194173942     0.582610  0.094756         854.049971
# 7988  1635194173942     0.589856  0.026031         833.515807
# 7989  1635194173942     0.530176  0.051015         888.532884
# 7990  1635194173942     0.513063  0.059889         872.706232
#
#       spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0            1946.914411  3411.299827            0.041226 -453.064362
# 1            2208.689401  4934.039862            0.101540 -311.985443
# ...

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)

# %%
df
# Out:
#            filename  chroma_stft      rmse  spectral_centroid  \
# 0     1586793423518     0.518146  0.006942        1429.256245
# 1     1586793423518     0.495280  0.034485        2157.372433
# 2     1586793423518     0.446874  0.036917        2905.736284
# 3     1586793423518     0.465129  0.053680        2636.513642
# 4     1586793423518     0.513032  0.027794        2382.390945
# ...             ...          ...       ...                ...
# 7986  1635194173942     0.562462  0.087709         936.160425
# 7987  1635194173942     0.582610  0.094756         854.049971
# 7988  1635194173942     0.589856  0.026031         833.515807
# 7989  1635194173942     0.530176  0.051015         888.532884
# 7990  1635194173942     0.513063  0.059889         872.706232
#
#       spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0            1946.914411  3411.299827            0.041226 -453.064362
# 1            2208.689401  4934.039862            0.101540 -311.985443
# ...

# %%
new
new = new.rename({'filenames': 'filename'}, axis=1)

# %%
labeled = pd.merge(new, df, how="inner", on=["filename"])

# %%
#labeled

# %%
labeled.to_csv('D:/COVID_COUGH_SOUNDS/MFCC/train/458_50MSoverlap.csv', index=False)

# %%
### TRAIN MACHINE LEARning model

# %%
labeled['correlation'] = pd.factorize(labeled['correlation'])[0]

# %%
labeled
# Out:
#            filename  correlation  chroma_stft      rmse  spectral_centroid  \
# 0     1629275449436            0     0.320837  0.010759        2003.683933
# 1     1629275449436            0     0.346080  0.027240        1527.669372
# 2     1629275449436            0     0.380794  0.007757        1161.919722
# 3     1629275449436            0     0.299199  0.074944        1244.898403
# 4     1629275449436            0     0.320349  0.101625        1440.939873
# ...             ...          ...          ...       ...                ...
# 7750  1586793423518            4     0.477289  0.039160        2502.477390
# 7751  1586793423518            4     0.487933  0.026454        2223.396190
# 7752  1586793423518            4     0.523521  0.030945        2053.139432
# 7753  1586793423518            4     0.478629  0.032930        2182.725485
# 7754  1586793423518            4     0.451423  0.025008        2218.250515
#
# ...

# %%
import pandas as pd
labeled = pd.read_csv('D:/COVID_COUGH_SOUNDS/MFCC/train/458_50MSoverlap.csv')

# %%
del labeled['filename']

# %%
labeled
# Out:
#       correlation  chroma_stft      rmse  spectral_centroid  \
# 0               0     0.320837  0.010759        2003.683933
# 1               0     0.346080  0.027240        1527.669372
# 2               0     0.380794  0.007757        1161.919722
# 3               0     0.299199  0.074944        1244.898403
# 4               0     0.320349  0.101625        1440.939873
# ...           ...          ...       ...                ...
# 7750            4     0.477289  0.039160        2502.477390
# 7751            4     0.487933  0.026454        2223.396190
# 7752            4     0.523521  0.030945        2053.139432
# 7753            4     0.478629  0.032930        2182.725485
# 7754            4     0.451423  0.025008        2218.250515
#
#       spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0            2395.170964  4464.469216            0.061867 -354.785065
# 1            2033.952055  3185.445890            0.051314 -341.541748
# ...

# %%
X = labeled.loc[:, labeled.columns != 'correlation']
y = labeled['correlation']

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
X= ms.fit_transform(X)

# %%
X = pd.DataFrame(X)

# %%
from sklearn.cluster import KMeans 

kmeans = KMeans (n_clusters = 5, random_state = 0 )
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
labels = kmeans.labels_
correct_labels = sum(y == labels)
print ('Result %d out of %d samples were correctly labeled.' %(correct_labels, y.size) )
# Out:
# Result 1810 out of 7755 samples were correctly labeled.

# %%
1810/7755
# Out:
# 0.23339780786589298

# %%
X = labeled.loc[:, labeled.columns != 'correlation']
y = labeled['correlation']

# %%
ms = MinMaxScaler()
X= ms.fit_transform(X)
X = pd.DataFrame(X)

# %%
from sklearn.metrics import accuracy_score

from sklearn.svm import SVC
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
seed= 9001
np.random.seed(seed)
x_tr, x_ts, y_tr, y_ts = train_test_split( X, y, test_size = 0.20, random_state =seed)

# %%
model =SVC()
model.fit (x_tr, y_tr)
# Out:
# SVC()

# %%
predict_cough_type = model.predict(x_ts)
print ('Accuracy: ', accuracy_score (y_ts, predict_cough_type))
# Out:
# Accuracy:  0.5938104448742747

# %%
X = labeled.loc[:, labeled.columns != 'correlation']
y = labeled['correlation']
ms = MinMaxScaler()
X= ms.fit_transform(X)
X = pd.DataFrame(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    stratify=y, 
                                                    test_size=0.20)

# %%
model =SVC()
model.fit (X_train, y_train)
# Out:
# SVC()

# %%
predict_cough_type = model.predict(X_test)
print ('Accuracy: ', accuracy_score (y_test, predict_cough_type))
# Out:
# Accuracy:  0.5809155383623469

# %%
labeled['correlation'].value_counts()
# Out:
# 4    3544
# 3    1824
# 2     943
# 1     870
# 0     574
# Name: correlation, dtype: int64

# %%
X = labeled.loc[:, labeled.columns != 'correlation']
y = labeled['correlation']
ms = MinMaxScaler()
X= ms.fit_transform(X)
X = pd.DataFrame(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    #stratify=y, 
                                                    test_size=0.20,
                                                   random_state = 4)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict_cough_type = rf.predict(X_test)
print ('Accuracy: ', accuracy_score (y_test, predict_cough_type))
#predict_cough_type = rf.predict(X_test)
#print ('Accuracy: ', accuracy_score (y_test, predict_cough_type))

from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, predict_cough_type)
## confusion matrix
# Out:
# Accuracy:  0.7401676337846551
# array([[ 35,   0,   1,   9,  68],
#        [  0,  76,   2,  26,  60],
#        [  0,   1,  75,  28,  73],
#        [  1,   0,   5, 290,  79],
#        [  1,   2,   7,  40, 672]], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
Log_REG = LogisticRegression(solver = 'lbfgs')
Log_REG.fit(X_train, y_train)
# Out:
# C:\Users\salta\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Log_REG.score(X_test, y_test)
# Out:
# 0.4951644100580271

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    #stratify=y, 
                                                    test_size=0.33,
                                                   random_state = 324)

# %%
from sklearn.tree import DecisionTreeClassifier
dec_tree_classifier  = DecisionTreeClassifier (max_leaf_nodes = 10, random_state =0)
dec_tree_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10, random_state=0)

# %%
y_predicted  = dec_tree_classifier.predict(X_test)

# %%
accuracy_score(y_test, y_predicted)*100
# Out:
# 51.6015625

# %%
target_col = 'correlation'
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.33, random_state=42)

# %%
import pandas as pd
import os
import numpy as np
np.set_printoptions(precision=4)
import catboost
from catboost import *
from catboost import datasets

# %%
import catboost

from catboost import CatBoostClassifier

# %%
model_Cat_boost = CatBoostClassifier(#task_type ='GPU',
                                    iterations = 20,
                                    random_state =2021)
                                    #eval_metric ='F1')

# %%
model_Cat_boost.fit(X_train, y_train, plot ='True',
                   eval_set =(X_test, y_test))
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Learning rate set to 0.490338
# 0:	learn: 1.3641154	test: 1.3895976	best: 1.3895976 (0)	total: 192ms	remaining: 3.65s
# 1:	learn: 1.2902019	test: 1.3305875	best: 1.3305875 (1)	total: 207ms	remaining: 1.86s
# 2:	learn: 1.2390128	test: 1.2953038	best: 1.2953038 (2)	total: 221ms	remaining: 1.25s
# 3:	learn: 1.2026404	test: 1.2777862	best: 1.2777862 (3)	total: 234ms	remaining: 938ms
# 4:	learn: 1.1740563	test: 1.2683074	best: 1.2683074 (4)	total: 247ms	remaining: 742ms
# 5:	learn: 1.1342941	test: 1.2416462	best: 1.2416462 (5)	total: 260ms	remaining: 607ms
# 6:	learn: 1.1054679	test: 1.2243991	best: 1.2243991 (6)	total: 273ms	remaining: 507ms
# 7:	learn: 1.0790573	test: 1.2153784	best: 1.2153784 (7)	total: 285ms	remaining: 428ms
# 8:	learn: 1.0610704	test: 1.2043062	best: 1.2043062 (8)	total: 298ms	remaining: 364ms
# 9:	learn: 1.0417359	test: 1.1974012	best: 1.1974012 (9)	total: 310ms	remaining: 310ms
# ...

# %%
from sklearn.metrics import accuracy_score
y_pred  = model_Cat_boost.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.5683217859892224

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.25, random_state=42)

# %%
from xgboost import XGBRegressor

my_model = XGBRegressor()
# Add silent=True to avoid printing out updates with each cycle
my_model.fit(X_train, y_train, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
predictions = my_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, y_test)))
# Out:
# Mean Absolute Error : 0.8972218680892441

# %%
my_model = XGBRegressor(n_estimators=1000, learning_rate=0.05)
my_model.fit(X_train, y_train, early_stopping_rounds=5, 
             eval_set=[(X_test, y_test)], verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
predictions = my_model.predict(X_test)

# %%
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, y_test)))
# Out:
# Mean Absolute Error : 0.8828219066826937
